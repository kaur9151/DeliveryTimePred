# %%
import pandas as pd

# %%
#Data Ingestion step
df=pd.read_csv('data/finalTrain.csv')

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 0      0xcdcd      DEHRES17DEL01                 36.0  \
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 0                          4.2            30.327968             78.046106  \
# 1                          4.7            10.003064             76.307589
# 2                          4.7            18.562450             73.916619
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Delivery_person_Ratings'].fillna(df['Delivery_person_Ratings'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
df.groupby(['Delivery_person_Age','Delivery_person_Ratings'])['Delivery_person_age'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.groupby(['Delivery_person_Age','Delivery_person_Ratings'])['Delivery_person_age'].mean()
#
# File c:\Users\User\Desktop\DeliveryTimePred\venv\lib\site-packages\pandas\core\groupby\generic.py:1771, in DataFrameGroupBy.__getitem__(self, key)
#    1764 if isinstance(key, tuple) and len(key) > 1:
#    1765     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1766     # valid syntax, so don't raise
#    1767     raise ValueError(
#    1768         "Cannot subset columns with a tuple with more than one element. "
#    1769         "Use a list instead."
#    1770     )
# -> 1771 return super().__getitem__(key)
#
# File c:\Users\User\Desktop\DeliveryTimePred\venv\lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
# ...

# %%
df['Delivery_person_Age'].median()
# Out:
# 30.0

# %%
df['Delivery_person_Age'].fillna(df['Delivery_person_Age'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
df=df.drop(['ID'],axis=1)

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0      DEHRES17DEL01                 36.0                      4.2  \
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
df=df.drop(['Delivery_person_ID'],axis=1)

# %%
#df=df.drop(['Time_Orderd'],axis=1)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# ...

# %%
df.isnull().sum()
# Out:
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
df['Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Sunny         7282
# Name: count, dtype: int64

# %%
df['Road_traffic_density'].value_counts()
# Out:
# Road_traffic_density
# Low       15476
# Jam       14139
# Medium    10945
# High       4423
# Name: count, dtype: int64

# %%
df=df.dropna(subset=['Weather_conditions'])

# %%
df.isnull().sum()
# Out:
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1115
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             981
# Festival                        225
# City                           1178
# Time_taken (min)                  0
# dtype: int64

# %%
df['multiple_deliveries'].unique()
# Out:
# array([ 3.,  1.,  0., nan,  2.])

# %%
df['multiple_deliveries'].value_counts()
# Out:
# multiple_deliveries
# 1.0    27779
# 0.0    13898
# 2.0     1956
# 3.0      354
# Name: count, dtype: int64

# %%
df['multiple_deliveries'].median()
# Out:
# 1.0

# %%
df['Festival'].value_counts()
# Out:
# Festival
# No     43865
# Yes      878
# Name: count, dtype: int64

# %%
df=df.dropna(subset=['multiple_deliveries','City','Festival'],how='all')

# %%
df.isnull().sum()
# Out:
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1115
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             980
# Festival                        224
# City                           1177
# Time_taken (min)                  0
# dtype: int64

# %%
df['multiple_deliveries']=df['multiple_deliveries'].ffill()

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# ...

# %%
df['Festival']=df['Festival'].bfill()

# %%
df['City'].value_counts()
# Out:
# City
# Metropolitian    33611
# Urban            10016
# Semi-Urban         163
# Name: count, dtype: int64

# %%
df=df.dropna(subset=['City'])

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# ...

# %%
df.isnull().sum()
# Out:
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1081
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken (min)                  0
# dtype: int64

# %%
#Segregate numerical and categorical columns
numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:",numerical_columns)
print("Categorical Columns:",categorical_columns)
# Out:
# Numerical columns: Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Vehicle_condition',
#        'multiple_deliveries', 'Time_taken (min)'],
#       dtype='object')
# Categorical Columns: Index(['Order_Date', 'Time_Orderd', 'Time_Order_picked', 'Weather_conditions',
#        'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle', 'Festival',
#        'City'],
#       dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#         Order_Date Time_Orderd Time_Order_picked Weather_conditions
# count        43790       42709             43790              43790  \
# unique          44         176               193                  6
# top     15-03-2022       21:55             21:30                Fog
# freq          1148         452               476               7482
#
#        Road_traffic_density Type_of_order Type_of_vehicle Festival
# count                 43790         43790           43790    43790  \
# unique                    4             4               3        2
# top                     Low         Snack      motorcycle       No
# freq                  14936         11038           25649    42917
#
#                  City
# count           43790
# unique              3
# top     Metropolitian
# freq            33611

# %%
df['Order_Date'].unique()
# Out:
# array(['12-02-2022', '13-02-2022', '04-03-2022', '14-02-2022',
#        '02-04-2022', '01-03-2022', '16-03-2022', '20-03-2022',
#        '15-02-2022', '10-03-2022', '11-03-2022', '27-03-2022',
#        '26-03-2022', '05-04-2022', '12-03-2022', '01-04-2022',
#        '05-03-2022', '11-02-2022', '08-03-2022', '03-04-2022',
#        '30-03-2022', '28-03-2022', '18-03-2022', '14-03-2022',
#        '06-04-2022', '04-04-2022', '24-03-2022', '19-03-2022',
#        '09-03-2022', '25-03-2022', '02-03-2022', '13-03-2022',
#        '29-03-2022', '31-03-2022', '17-03-2022', '07-03-2022',
#        '15-03-2022', '16-02-2022', '03-03-2022', '18-02-2022',
#        '23-03-2022', '17-02-2022', '06-03-2022', '21-03-2022'],
#       dtype=object)

# %%
df['Order_Date']=pd.to_datetime(df['Order_Date'],format="%d-%m-%Y")

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106 2022-02-12       21:55             22:10  \
# 1                    76.347589 2022-02-13       14:55             15:05
# ...

# %%
df['month']=df['Order_Date'].dt.month

# %%
df['month'].dtype
# Out:
# dtype('int32')

# %%
df['day']=df['Order_Date'].dt.day

# %%
df.head()
df['day']
# Out:
# 0        12
# 1        13
# 2         4
# 3        13
# 4        14
#          ..
# 45579    24
# 45580    16
# 45581    11
# 45582     7
# 45583     2
# Name: day, Length: 43790, dtype: int32

# %%
df.drop('Order_Date',axis=1)
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                     36.0                      4.2            30.327968  \
# 1                     21.0                      4.7            10.003064
# 2                     23.0                      4.7            18.562450
# 3                     34.0                      4.3            30.899584
# 4                     24.0                      4.7            26.463504
# ...                    ...                      ...                  ...
# 45579                 30.0                      4.8            26.902328
# 45580                 21.0                      4.6             0.000000
# 45581                 30.0                      4.9            13.022394
# 45582                 20.0                      4.7            11.001753
# 45583                 23.0                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude
# ...

# %%
#Segregate numerical and categorical columns
numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:",numerical_columns)
print("Categorical Columns:",categorical_columns)
# Out:
# Numerical columns: Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Vehicle_condition',
#        'multiple_deliveries', 'Time_taken (min)', 'month', 'day'],
#       dtype='object')
# Categorical Columns: Index(['Time_Orderd', 'Time_Order_picked', 'Weather_conditions',
#        'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle', 'Festival',
#        'City'],
#       dtype='object')

# %%
df['Time_Order_picked']
# Out:
# 0           22:10
# 1           15:05
# 2           17:40
# 3           09:30
# 4           20:05
#            ...
# 45579       11:45
# 45580       20:10
# 45581    24:05:00
# 45582       13:40
# 45583       17:15
# Name: Time_Order_picked, Length: 43790, dtype: object

# %%
str(df['Time_Order_picked'])
# Out:
# '0           22:10\n1           15:05\n2           17:40\n3           09:30\n4           20:05\n           ...   \n45579       11:45\n45580       20:10\n45581    24:05:00\n45582       13:40\n45583       17:15\nName: Time_Order_picked, Length: 45584, dtype: object'

# %%
df[['Hour','minute','second']]=df.Time_Order_picked.str.split(":",expand=True)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106 2022-02-12       21:55             22:10  \
# 1                    76.347589 2022-02-13       14:55             15:05
# ...

# %%
df=df.drop('second',axis=1)

# %%
df=df.drop('minute',axis=1)

# %%
df=df.drop('Time_Order_picked',axis=1)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Weather_conditions
# 0                    78.116106 2022-02-12       21:55                Fog  \
# 1                    76.347589 2022-02-13       14:55             Stormy
# ...

# %%
df['Hour'].value_counts()
# Out:
# Hour
# 21             4243
# 18             4198
# 20             4167
# 22             4156
# 19             4127
# 23             4062
# 17             3469
# 10             1833
# 11             1758
# 09             1751
# 08             1440
# 12              947
# 24              830
# 15              772
# 14              712
# 13              685
# 16              657
# 0.833333333     438
# 0.916666667     419
# 1               412
# 0.75            410
# 0.875           402
# 0.958333333     401
# 0.791666667     389
# 0.375           195
# 0.416666667     185
# 0.5             182
# 0.458333333     142
# 0.625            94
# 0.666666667      90
# 0.583333333      81
# 0.541666667      78
# 0.708333333      65
# Name: count, dtype: int64

# %%
df['Hour']=df['Hour'].astype(float)
#df['Hour'].map(lambda x: x*10)

# %%
df.drop('Order_Date',axis=1)
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                     36.0                      4.2            30.327968  \
# 1                     21.0                      4.7            10.003064
# 2                     23.0                      4.7            18.562450
# 3                     34.0                      4.3            30.899584
# 4                     24.0                      4.7            26.463504
# ...                    ...                      ...                  ...
# 45579                 30.0                      4.8            26.902328
# 45580                 21.0                      4.6             0.000000
# 45581                 30.0                      4.9            13.022394
# 45582                 20.0                      4.7            11.001753
# 45583                 23.0                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude
# ...

# %%
for Hour in df:
    print(df[Hour])
# Out:
# 0        36.0
# 1        21.0
# 2        23.0
# 3        34.0
# 4        24.0
#          ...
# 45579    30.0
# 45580    21.0
# 45581    30.0
# 45582    20.0
# 45583    23.0
# Name: Delivery_person_Age, Length: 43790, dtype: float64
# 0        4.2
# 1        4.7
# 2        4.7
# 3        4.3
# 4        4.7
#         ...
# 45579    4.8
# 45580    4.6
# 45581    4.9
# 45582    4.7
# 45583    4.9
# Name: Delivery_person_Ratings, Length: 43790, dtype: float64
# 0        30.327968
# 1        10.003064
# 2        18.562450
# 3        30.899584
# 4        26.463504
#            ...
# 45579    26.902328
# 45580     0.000000
# 45581    13.022394
# 45582    11.001753
# 45583    23.351058
# Name: Restaurant_latitude, Length: 43790, dtype: float64
# 0        78.046106
# 1        76.307589
# 2        73.916619
# 3        75.809346
# 4        80.372929
#            ...
# 45579    75.794257
# 45580     0.000000
# 45581    80.242439
# 45582    76.986241
# 45583    85.325731
# ...

# %%
def time(x):
    if x<1:
        x=y

# %%
df['Hour'].values
# Out:
# array([22., 15., 17., ..., 24., 13., 17.])

# %%
df2=pd.read_csv('data/finalTrain.csv')
df2[['Hour','minute']]=df2.Time_Orderd.str.split(":",expand=True)
x=df['Hour'].values
y=df2['Hour'].values
##print(y)
for i in range(len(x)):
    if x[i]<1:
        #print(x[i])
        x[i]=float(y[i])
print(x)
# Out:
# [22. 15. 17. ... 24. 13. 17.]

# %%
df2[['Hour','minute']]=df2.Time_Orderd.str.split(":",expand=True)

# %%
for i in df['Hour'].values:
    if i<1:
        print(i)
# Out:
# 0.458333333
# 0.791666667
# 0.5
# 0.708333333
# 0.5
# 0.916666667
# 0.416666667
# 0.75
# 0.416666667
# 0.833333333
# 0.916666667
# 0.833333333
# 0.916666667
# 0.916666667
# 0.5
# 0.916666667
# 0.75
# 0.916666667
# 0.791666667
# 0.875
# 0.875
# 0.916666667
# 0.833333333
# 0.791666667
# 0.375
# 0.375
# 0.583333333
# 0.916666667
# 0.875
# 0.75
# 0.541666667
# 0.875
# 0.791666667
# 0.916666667
# 0.458333333
# 0.625
# 0.833333333
# 0.791666667
# 0.416666667
# 0.75
# 0.958333333
# 0.916666667
# 0.875
# 0.791666667
# 0.791666667
# 0.75
# 0.75
# 0.75
# 0.625
# 0.916666667
# 0.416666667
# 0.958333333
# 0.708333333
# 0.916666667
# 0.833333333
# 0.458333333
# 0.958333333
# 0.375
# 0.416666667
# 0.833333333
# 0.875
# 0.958333333
# 0.875
# 0.791666667
# 0.833333333
# 0.916666667
# 0.875
# 0.875
# 0.375
# 0.458333333
# 0.916666667
# 0.833333333
# 0.833333333
# 0.416666667
# 0.833333333
# 0.666666667
# 0.875
# 0.875
# 0.5
# 0.875
# 0.833333333
# 0.958333333
# 0.5
# 0.541666667
# 0.875
# ...

# %%
import numpy as np
for i in df2['Hour'].values:
    print(i)
    np.where(df['Hour']<1, i, df['Hour'])
# Out:
# 21
# 14
# 17
# 09
# 19
# 20
# 14
# 20
# 20
# 21
# 20
# 22
# 08
# 19
# 12
# 18
# 20
# 23
# 21
# 23
# 22
# 22
# 23
# 13
# 21
# 22
# 18
# 14
# 0.458333333
# 09
# 08
# 0.958333333
# 17
# nan
# 19
# 19
# 10
# 21
# 0.791666667
# 16
# 11
# 15
# 22
# 22
# 20
# 22
# 17
# 22
# 20
# 09
# 20
# 22
# 21
# 22
# 23
# 15
# 10
# 20
# 10
# 15
# 20
# 12
# 15
# 22
# 10
# nan
# 23
# 21
# 20
# 20
# 12
# 0.875
# 23
# 18
# 18
# 11
# 20
# 21
# 12
# 23
# 10
# 21
# 10
# 0.958333333
# 08
# 17
# 20
# 22
# 23
# 23
# 12
# 23
# 23
# 22
# 10
# 08
# 21
# 22
# 20
# 10
# 20
# 23
# 10
# 23
# 19
# 22
# 23
# 09
# 18
# 22
# 20
# nan
# 18
# 14
# 16
# 22
# 1
# 21
# 23
# 23
# 14
# 10
# 21
# 08
# 0.375
# 17
# 23
# 16
# 08
# 20
# 23
# nan
# 19
# 21
# 21
# 19
# 14
# 18
# 12
# 23
# 12
# 23
# 17
# 10
# 09
# 12
# 17
# 19
# 23
# 18
# 20
# 22
# 17
# 19
# 18
# 23
# 17
# 23
# 18
# 21
# 08
# 22
# 11
# 23
# 19
# 18
# 18
# 22
# 0.791666667
# 13
# nan
# 17
# 19
# 21
# 19
# 19
# 21
# 09
# 20
# 21
# 0.958333333
# 0.625
# 19
# 17
# 0.375
# ...

# %%
df['Final_Hour']=df['Hour']
df.loc[df['Hour']<1,'Final_Hour']=df2['Hour']

# %%
df['Final_Hour'].unique()
# Out:
# array([22.0, 15.0, 17.0, 9.0, 20.0, 21.0, 8.0, 19.0, 12.0, 18.0, 23.0,
#        13.0, 14.0, 11.0, 10.0, 16.0, 24.0, nan, 1.0, '18', '20', '21',
#        '22', '10', '16', '19', '11', '09', '12', '13', '08', '17', '15',
#        '14'], dtype=object)

# %%
df['Final_Hour'].isnull().sum()
# Out:
# 147

# %%
df['Hour'].isnull().sum()
# Out:
# 144

# %%
df['Final_Hour']=df['Final_Hour'].ffill()

# %%
df['Final_Hour']=df['Final_Hour'].astype(int)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Weather_conditions
# 0                    78.116106 2022-02-12       21:55                Fog  \
# 1                    76.347589 2022-02-13       14:55             Stormy
# ...

# %%
df=df.drop('Hour',axis=1)

# %%
df=df.drop('Order_Date',axis=1)

# %%
df=df.drop('Time_Orderd',axis=1)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Weather_conditions Road_traffic_density
# 0                    78.116106                Fog                  Jam  \
# 1                    76.347589             Stormy                 High
# ...

# %%
#Segregate numerical and categorical columns
numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:",numerical_columns)
print("Categorical Columns:",categorical_columns)
# Out:
# Numerical columns: Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Vehicle_condition',
#        'multiple_deliveries', 'Time_taken (min)', 'month', 'day',
#        'Final_Hour'],
#       dtype='object')
# Categorical Columns: Index(['Weather_conditions', 'Road_traffic_density', 'Type_of_order',
#        'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %%
df['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny'],
#       dtype=object)

# %%
df['Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Fog           7482
# Stormy        7386
# Cloudy        7361
# Sandstorms    7283
# Windy         7219
# Sunny         7059
# Name: count, dtype: int64

# %%
Weather_map={'Stormy':1,'Sandstorms':2,'windy':3,'Fog':4,'Cloudy':5,'Sunny':6}

# %%
df['Road_traffic_density'].unique()
# Out:
# array(['Jam', 'High', 'Medium', 'Low'], dtype=object)

# %%
traffic_map={'Jam':1,'High':2,'Medium':3,'Low':4}

# %%
df['Type_of_order'].unique()
# Out:
# array(['Snack', 'Meal', 'Drinks', 'Buffet'], dtype=object)

# %%
order_map={'Drinks':1,'Snack':2,'Meal':3,'Buffet':4}

# %%
df['Type_of_vehicle'].unique()
# Out:
# array(['motorcycle', 'scooter', 'electric_scooter'], dtype=object)

# %%
vehicle_map={'electric_scooter':1,'scooter':2,'motorcycle':3}

# %%
df['Festival'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
festival_map={'No':0,'Yes':1}

# %%
df['City'].unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban'], dtype=object)

# %%
city_map={'Semi-urban':1,'urban':2,'Metropolitian':3}

# %%
df['City']=df['City'].map(city_map)

# %%
df['Festival']=df['Festival'].map(festival_map)
df['Type_of_vehicle']=df['Type_of_vehicle'].map(vehicle_map)
df['Type_of_order']=df['Type_of_order'].map(order_map)
df['Road_traffic_density']=df['Road_traffic_density'].map(traffic_map)
df['Weather_conditions']=df['Weather_conditions'].map(Weather_map)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density
# 0                    78.116106                 4.0                     1  \
# 1                    76.347589                 1.0                     2
# ...

# %%
df.to_csv('EDA_done.csv')
